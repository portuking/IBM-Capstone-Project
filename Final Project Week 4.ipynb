# %% [markdown]
# # Introdution
# The idea of this project is locate the best Neightborhood in London to open a restaurant of Latin American food. To select the neighborood we are going to evaluate the immigration data in London and foursquare. This information can help a lot of businessmen and small businesses to establish their restaurants location. It would also help franchises to open a chain or modify their menu based on the likings of the people there in that particular area.

# %% [markdown]
# # Data
# The data that will be used is the is immigration data from London. The data will provide information about where people form Latin America is moving. Then we are going to compered that data with the data form foursquere to see where are existing restaurants of Latin American Food and see whhich are the most visited restaruants in each neighborhoods.

# %%
import pandas as pd

london=pd.read_csv('https://data.london.gov.uk/download/country-of-birth/aeeb0b0a-5b2f-48b3-a53e-e6c525858b31/cob-borough.csv')

# %%
london.head()
# Out:
#    Year  Area_Code             Area_Name Broad_group Detailed_group Estimate  \
# 0  2017  E09000001        City of London       Total          Total        :
# 1  2017  E09000002  Barking and Dagenham       Total          Total      210
# 2  2017  E09000003                Barnet       Total          Total      391
# 3  2017  E09000004                Bexley       Total          Total      247
# 4  2017  E09000005                 Brent       Total          Total      333
#
#   CI
# 0  :
# 1  z
# 2  z
# 3  z
# 4  z

# %%
london.Detailed_group.unique()
# Out:
# array(['Total', 'United Kingdom', 'Non-United Kingdom', 'All',
#        'European Union EU14', 'European Union EU8', 'European Union EU2',
#        'European Union Other', 'Other Europe',
#        'Middle East and Central Asia', 'East Asia', 'South Asia',
#        'South East Asia', 'Sub-Saharan Africa', 'North Africa',
#        'North America', 'Central and South America', 'Oceania'], dtype=object)

# %%
latin_central_america=london[london.Detailed_group== 'Central and South America']

# %%
latin_central_america
# Out:
#        Year  Area_Code                  Area_Name        Broad_group  \
# 882    2017  E09000001             City of London  Rest of the World
# 883    2017  E09000002       Barking and Dagenham  Rest of the World
# 884    2017  E09000003                     Barnet  Rest of the World
# 885    2017  E09000004                     Bexley  Rest of the World
# 886    2017  E09000005                      Brent  Rest of the World
# 887    2017  E09000006                    Bromley  Rest of the World
# 888    2017  E09000007                     Camden  Rest of the World
# 889    2017  E09000008                    Croydon  Rest of the World
# 890    2017  E09000009                     Ealing  Rest of the World
# 891    2017  E09000010                    Enfield  Rest of the World
# 892    2017  E09000011                  Greenwich  Rest of the World
# 893    2017  E09000012                    Hackney  Rest of the World
# 894    2017  E09000013     Hammersmith and Fulham  Rest of the World
# ...
